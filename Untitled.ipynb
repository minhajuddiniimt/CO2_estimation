# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('CO2.csv')

# %%
data.head()
# Out:
#    Engine_size  Cylinders  Fuel_consuption  CO2_estimation
# 0          2.0          4              8.5             196
# 1          2.4          4              9.6             221
# 2          1.5          4              5.9             136
# 3          3.5          6             11.1             255
# 4          3.5          6             10.6             244

# %%
sns.relplot(x="Engine_size", y="CO2_estimation", data=data)

# %%
sns.relplot(x="Engine_size", y="CO2_estimation", data=data, kind='line')

# %%
sns.set(style="darkgrid")

# %%
sns.relplot(x="Engine_size", y="CO2_estimation", data=data, kind='line')

# %%
sns.relplot(x="Engine_size", y="CO2_estimation", hue="Cylinders",data=data)
